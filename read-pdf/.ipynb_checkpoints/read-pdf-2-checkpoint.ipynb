# %%
# !brew install poppler
# !pip install pdfplumber pandas openpyxl
# Out:
# ==> Downloading https://formulae.brew.sh/api/formula.jws.json
# ######################################################################### 100.0%
# ==> Downloading https://formulae.brew.sh/api/cask.jws.json
# ######################################################################### 100.0%
# Warning: poppler 24.04.0_1 is already installed and up-to-date.
# To reinstall 24.04.0_1, run:
#   brew reinstall poppler
# Requirement already satisfied: pdfplumber in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (0.11.4)
# Requirement already satisfied: pandas in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: openpyxl in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (3.0.10)
# Requirement already satisfied: pdfminer.six==20231228 in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from pdfplumber) (20231228)
# Requirement already satisfied: Pillow>=9.1 in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from pdfplumber) (10.2.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from pdfplumber) (4.30.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from pdfminer.six==20231228->pdfplumber) (2.0.4)
# Requirement already satisfied: cryptography>=36.0.0 in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from pdfminer.six==20231228->pdfplumber) (41.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: et_xmlfile in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.15.1)
# Requirement already satisfied: pycparser in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.21)

# %%
import pdfplumber
import pandas as pd
import re

# %%
# Define a list to store parsed rows
records = []

# Path to the PDF file
pdf_path = './2024-final-assessment-roll-pages-1-3.pdf'


# Function to parse each section based on specific rules
def parse_text(section):
    lines = section.strip().splitlines()
    
    # Skip sections that don't have enough lines
    if len(lines) < 6:
        return None
    
    # Rule 1: Property Address (first line, ignore "HOMESTEAD" if present)
    property_address = lines[0].replace("HOMESTEAD", "").strip()
    
    # Exclude records with "PAGE: <number>" in Property Address
    if re.search(r'PAGE:\s*\d+', property_address):
        print(f"Skipping record due to PAGE in Property Address: {property_address}")
        return None

    # Rule 2: Property Type (second line, capture the entire type, but remove "TAXABLE" and anything after)
    property_type_match = re.search(r'\d{3}-\d{2}-\d-\d{1,2}-\d{1,2}\s+\d+\s+(.+)', lines[1])
    if property_type_match:
        property_type = property_type_match.group(1).strip()
        property_type = re.split(r'\s+TAXABLE', property_type)[0].strip()  # Remove text starting with "TAXABLE"
    else:
        property_type = None

    # Rule 3: Owner Name and School District (third line)
    # Capture names with up to three words and the remaining part as School District
    owner_school_line = lines[2].split()
    if len(owner_school_line) > 3:
        owner_name = " ".join(owner_school_line[:3])  # First three words for Owner Name
        school_district = " ".join(owner_school_line[3:])  # Remaining words for School District
    else:
        owner_name = " ".join(owner_school_line)
        school_district = lines[3] if len(lines) > 3 else None

    # Remove any content starting with a number in School District
    if school_district:
        school_district = re.split(r'\s+\d', school_district)[0].strip()

    # Rule 4: Zoning (fourth line, between address and "Acreage")
    zoning_match = re.search(r'^\d+\s+[\w\s]+(?=\sAcreage)', lines[3] if len(lines) > 3 else "")
    zoning = zoning_match.group(0).strip() if zoning_match else ""

    # Rule 5: Market Value (any number after "FULL MKT VAL" in the text)
    market_value_match = re.search(r'FULL MKT VAL\s+([\d,]+)', section)
    market_value = market_value_match.group(1) if market_value_match else None

    # Rule 6: Acreage (find "Acreage" followed by a number)
    acreage_match = re.search(r'Acreage\s+([\d.]+)', section, re.IGNORECASE)
    acreage = acreage_match.group(1) if acreage_match else None

    # Store extracted data in a dictionary
    data = {
        'Current Owner Name': owner_name,
        'Property Type': property_type,
        'Property Address': property_address,
        'School District': school_district,
        'Zoning': zoning,
        'Market Value': market_value,
        'Acreage': acreage  # New column for Acreage
    }
    return data

# Accumulate all page texts
all_text = ""

# Open the PDF and accumulate text from each page
with pdfplumber.open(pdf_path) as pdf:
    for page in pdf.pages:
        text = page.extract_text()
        if text:
            all_text += text + "\n"

# Define the pattern to split sections on any line with multiple asterisks
pattern = r'\*{10,}'  # Matches any line with 10 or more asterisks

# Split accumulated text based on the pattern
sections = re.split(pattern, all_text)

# Removing any empty sections that may result from splitting
sections = [section.strip() for section in sections if section.strip()]

# Process each section further if it contains multiple records (nested split)
for idx, section in enumerate(sections, start=1):
    # Split each section further if it has additional asterisk lines indicating multiple records
    sub_sections = re.split(r'\*{10,}', section)
    
    # Process each sub-section as an individual record
    for sub_section in sub_sections:
        sub_section = sub_section.strip()
        if not sub_section:
            continue
        
        print(f"Processing Record in Section {idx}:\n{sub_section}\n{'-'*40}")
        
        # Parse each sub-section and add to records if valid
        record = parse_text(sub_section)
        if record:
            records.append(record)

# Create a DataFrame and save to Excel
df = pd.DataFrame(records)
df.to_excel("extracted_property_data.xlsx", index=False)

# Print the count of records
print(f"Total number of records extracted: {len(records)}")

print("Data has been extracted and saved to 'extracted_property_data.xlsx'")
# Out:
# Processing Record in Section 1:
# STATE OF NEW YORK 2024 C I T Y F I N A L R O L L PAGE: 1
# COUNTY: WESTCHESTER T A X A B L E SECTION OF THE ROLL - 1 ROLL PRINT DATE: 9/16/2024
# CITY OF RYE PARCEL ID ORDER VALUATION DATE: 7/1/2023
# SWIS: 551400 (CITY OF RYE) UNIFORM PERCENT OF VALUE = 1.26 TAXABLE STATUS DATE: 5/1/2024
# TAX MAP PARCEL ID CD PROPERTY LOCATION & CLASS ASSESSMENT EXEMPTION CODE-----------COUNTY-----CITY-----SCHOOL
# CURRENT OWNERS NAME SCHOOL DISTRICT ---LAND--- TAX DESCRIPTION TAXABLE VALUE
# CURRENT OWNERS ADDRESS PARCEL SIZE/GRID COORD --TOTAL--- SPECIAL DISTRICTS
# ----------------------------------------
# Skipping record due to PAGE in Property Address: STATE OF NEW YORK 2024 C I T Y F I N A L R O L L PAGE: 1
# Processing Record in Section 2:
# 139-15-1-1-1
# ----------------------------------------
# Processing Record in Section 3:
# 100 RIDGE ST HOMESTEAD
# 139-15-1-1-1 210 1 FAMILY RES COUNTY TAXABLE 42,000
# THAIN JOHN A RYE CITY SCHOOLS 20,200 CITY TAXABLE 42,000
# 350 PURCHASE ST ACREAGE 3.57 SCHOOL TAXABLE 42,000
# RYE NY 10580 DEED BK 53220 PG 03634 42,000 TXBBS BLIND BROOK SEW 42,000 TO C
# FULL MKT VAL 3,333,333 TXCWD CO WATER DIST 42,000 TO M
# TXREF REFUSE DISPOSAL 42,000 TO M
# ----------------------------------------
# Processing Record in Section 4:
# 139-15-1-1-2
# ----------------------------------------
# Processing Record in Section 5:
# 95 RIDGE ST HOMESTEAD
# 139-15-1-1-2 210 1 FAMILY RES COUNTY TAXABLE 18,000
# THAIN CARMEN RIBERA RYE CITY SCHOOLS 14,400 CITY TAXABLE 18,000
# 350 PURCHASE STREET ACREAGE 1.48 SCHOOL TAXABLE 18,000
# RYE NY 10580 DEED BK 41054 PG 589 18,000 TXBBS BLIND BROOK SEW 18,000 TO C
# FULL MKT VAL 1,428,571 TXCWD CO WATER DIST 18,000 TO M
# TXREF REFUSE DISPOSAL 18,000 TO M
# ----------------------------------------
# Processing Record in Section 6:
# 139-15-1-1-3
# ----------------------------------------
# Processing Record in Section 7:
# 85 RIDGE ST HOMESTEAD
# 139-15-1-1-3 210 1 FAMILY RES 41834 SR STAR 3,210
# PETERS JONATHAN W RYE CITY SCHOOLS 12,400 COUNTY TAXABLE 28,000
# 85 RIDGE ST ACREAGE 1.36 CITY TAXABLE 28,000
# RYE NY 10580 FULL MKT VAL 2,222,222 28,000 SCHOOL TAXABLE 24,790
# TXBBS BLIND BROOK SEW 28,000 TO C
# TXCWD CO WATER DIST 28,000 TO M
# TXREF REFUSE DISPOSAL 28,000 TO M
# ----------------------------------------
# Processing Record in Section 8:
# 139-15-1-1-4
# ----------------------------------------
# Processing Record in Section 9:
# 75 RIDGE ST HOMESTEAD
# 139-15-1-1-4 311 RES VACANT LAND COUNTY TAXABLE 90,900
# THAIN JOHN A & RYE CITY SCHOOLS 90,900 CITY TAXABLE 90,900
# CARMEN M THAIN ACREAGE 10.59 SCHOOL TAXABLE 90,900
# 350 PURCHASE ST FULL MKT VAL 7,214,285 90,900 TXBBS BLIND BROOK SEW 90,900 TO C
# RYE NY 10580 TXCWD CO WATER DIST 90,900 TO M
# TXREF REFUSE DISPOSAL 90,900 TO M
# ----------------------------------------
# Processing Record in Section 10:
# 139-15-1-2
# ----------------------------------------
# Processing Record in Section 11:
# 70 RIDGE ST HOMESTEAD
# 139-15-1-2 210 1 FAMILY RES COUNTY TAXABLE 27,700
# TIDMAN MATTHEW RYE CITY SCHOOLS 8,000 CITY TAXABLE 27,700
# TIDMAN LIANNE ACREAGE 1.07 SCHOOL TAXABLE 27,700
# 70 RIDGE ST DEED BK 62081 PG 4109 27,700 TXBBS BLIND BROOK SEW 27,700 TO C
# RYE NY 10580 BANK COR TXCWD CO WATER DIST 27,700 TO M
# FULL MKT VAL 2,198,412 TXREF REFUSE DISPOSAL 27,700 TO M
# ----------------------------------------
# Processing Record in Section 12:
# STATE OF NEW YORK 2024 C I T Y F I N A L R O L L PAGE: 2
# COUNTY: WESTCHESTER T A X A B L E SECTION OF THE ROLL - 1 ROLL PRINT DATE: 9/16/2024
# CITY OF RYE PARCEL ID ORDER VALUATION DATE: 7/1/2023
# SWIS: 551400 (CITY OF RYE) UNIFORM PERCENT OF VALUE = 1.26 TAXABLE STATUS DATE: 5/1/2024
# TAX MAP PARCEL ID CD PROPERTY LOCATION & CLASS ASSESSMENT EXEMPTION CODE-----------COUNTY-----CITY-----SCHOOL
# CURRENT OWNERS NAME SCHOOL DISTRICT ---LAND--- TAX DESCRIPTION TAXABLE VALUE
# CURRENT OWNERS ADDRESS PARCEL SIZE/GRID COORD --TOTAL--- SPECIAL DISTRICTS
# ----------------------------------------
# Skipping record due to PAGE in Property Address: STATE OF NEW YORK 2024 C I T Y F I N A L R O L L PAGE: 2
# Processing Record in Section 13:
# 139-15-1-3
# ----------------------------------------
# Processing Record in Section 14:
# 127 EVERGREEN AVE HOMESTEAD
# 139-15-1-3 210 1 FAMILY RES COUNTY TAXABLE 50,700
# ALLISON RICHARD D RYE CITY SCHOOLS 11,000 CITY TAXABLE 50,700
# 127 EVERGREEN AVE ACREAGE 1.31 SCHOOL TAXABLE 50,700
# RYE NY 10580 DEED BK 60188 PG 3599 50,700 TXBBS BLIND BROOK SEW 50,700 TO C
# FULL MKT VAL 4,023,809 TXCWD CO WATER DIST 50,700 TO M
# TXREF REFUSE DISPOSAL 50,700 TO M
# ----------------------------------------
# Processing Record in Section 15:
# 139-15-1-4
# ----------------------------------------
# Processing Record in Section 16:
# 110 EVERGREEN AVE HOMESTEAD
# 139-15-1-4 210 1 FAMILY RES COUNTY TAXABLE 43,150
# LESTER WILLIAM G RYE CITY SCHOOLS 9,400 CITY TAXABLE 43,150
# LESTER DEIRDRE G ACREAGE 1.00 SCHOOL TAXABLE 43,150
# 50 CAMPDEN HILL SQUARE DEED BK 53219 PG 03495 43,150 TXBBS BLIND BROOK SEW 43,150 TO C
# LONDON ,UNITED KINGDOM BANK INT TXCWD CO WATER DIST 43,150 TO M
# FULL MKT VAL 3,424,603 TXREF REFUSE DISPOSAL 43,150 TO M
# ----------------------------------------
# Processing Record in Section 17:
# 139-15-1-5
# ----------------------------------------
# Processing Record in Section 18:
# 149 GRANDVIEW AVE HOMESTEAD
# 139-15-1-5 210 1 FAMILY RES COUNTY TAXABLE 76,450
# RUSK JENNIFER E RYE CITY SCHOOLS 9,450 CITY TAXABLE 76,450
# TALIA JOSEPH A ACREAGE 1.11 SCHOOL TAXABLE 76,450
# 149 GRANDVIEW AVE DEED BK 61069 PG 3514 76,450 TXBBS BLIND BROOK SEW 76,450 TO C
# RYE NY 10580 BANK COR TXCWD CO WATER DIST 76,450 TO M
# FULL MKT VAL 6,067,460 TXREF REFUSE DISPOSAL 76,450 TO M
# ----------------------------------------
# Processing Record in Section 19:
# 139-15-1-7
# ----------------------------------------
# Processing Record in Section 20:
# 164 GRANDVIEW AVE HOMESTEAD
# 139-15-1-7 210 1 FAMILY RES COUNTY TAXABLE 1,720
# REES TIMOTHY M RYE CITY SCHOOLS 1,720 CITY TAXABLE 1,720
# REES CECELIA C ACREAGE 0.20 SCHOOL TAXABLE 1,720
# 164 GRANDVIEW AVE DEED BK 60204 PG 3677 1,720 TXBBS BLIND BROOK SEW 1,720 TO C
# RYE NY 10580 FULL MKT VAL 136,507 TXCWD CO WATER DIST 1,720 TO M
# TXREF REFUSE DISPOSAL 1,720 TO M
# ----------------------------------------
# Processing Record in Section 21:
# 139-15-1-8
# ----------------------------------------
# Processing Record in Section 22:
# 142 GRANDVIEW AVE HOMESTEAD
# 139-15-1-8 210 1 FAMILY RES COUNTY TAXABLE 21,200
# MC GOVERN PATRICK & RYE CITY SCHOOLS 5,700 CITY TAXABLE 21,200
# SUSAN MC GOVERN ACREAGE 0.30 SCHOOL TAXABLE 21,200
# 142 GRANDVIEW AVE BANK COR 21,200 TXBBS BLIND BROOK SEW 21,200 TO C
# RYE NY 10580 FULL MKT VAL 1,682,539 TXCWD CO WATER DIST 21,200 TO M
# TXREF REFUSE DISPOSAL 21,200 TO M
# ----------------------------------------
# Processing Record in Section 23:
# 139-15-1-9-1
# ----------------------------------------
# Processing Record in Section 24:
# 138 GRANDVIEW AVE HOMESTEAD
# 139-15-1-9-1 GD 210 1 FAMILY RES COUNTY TAXABLE 26,610
# SAVAGE FRANK A & RYE CITY SCHOOLS 6,750 CITY TAXABLE 26,610
# CYNTHIA SAVAGE ACREAGE 0.39 SCHOOL TAXABLE 26,610
# 138 GRANDVIEW AVE FULL MKT VAL 2,111,904 26,610 TXBBS BLIND BROOK SEW 26,610 TO C
# RYE NY 10580 TXCWD CO WATER DIST 26,610 TO M
# TXREF REFUSE DISPOSAL 26,610 TO M
# ----------------------------------------
# Processing Record in Section 25:
# STATE OF NEW YORK 2024 C I T Y F I N A L R O L L PAGE: 3
# COUNTY: WESTCHESTER T A X A B L E SECTION OF THE ROLL - 1 ROLL PRINT DATE: 9/16/2024
# CITY OF RYE PARCEL ID ORDER VALUATION DATE: 7/1/2023
# SWIS: 551400 (CITY OF RYE) UNIFORM PERCENT OF VALUE = 1.26 TAXABLE STATUS DATE: 5/1/2024
# TAX MAP PARCEL ID CD PROPERTY LOCATION & CLASS ASSESSMENT EXEMPTION CODE-----------COUNTY-----CITY-----SCHOOL
# CURRENT OWNERS NAME SCHOOL DISTRICT ---LAND--- TAX DESCRIPTION TAXABLE VALUE
# CURRENT OWNERS ADDRESS PARCEL SIZE/GRID COORD --TOTAL--- SPECIAL DISTRICTS
# ----------------------------------------
# Skipping record due to PAGE in Property Address: STATE OF NEW YORK 2024 C I T Y F I N A L R O L L PAGE: 3
# Processing Record in Section 26:
# 139-15-1-9-2
# ----------------------------------------
# Processing Record in Section 27:
# GRANDVIEW AVE HOMESTEAD
# 139-15-1-9-2 GD 311 RES VACANT LAND COUNTY TAXABLE 1,000
# MELNICK JAMES R RYE CITY SCHOOLS 1,000 CITY TAXABLE 1,000
# BRYAN MARY K V DEED BK 61024 PG 3026 SCHOOL TAXABLE 1,000
# 164 JULIAN ST BANK COR 1,000 TXBBS BLIND BROOK SEW 1,000 TO C
# RYE NY 10580 FULL MKT VAL 79,365 TXCWD CO WATER DIST 1,000 TO M
# TXREF REFUSE DISPOSAL 1,000 TO M
# ----------------------------------------
# Processing Record in Section 28:
# 139-15-1-10
# ----------------------------------------
# Processing Record in Section 29:
# 132 GRANDVIEW AVE HOMESTEAD
# 139-15-1-10 210 1 FAMILY RES COUNTY TAXABLE 36,500
# CALISE ANDREA RYE CITY SCHOOLS 5,600 CITY TAXABLE 36,500
# MCLEOD LINDA ACREAGE 0.29 SCHOOL TAXABLE 36,500
# 132 GRANDVIEW AVE DEED BK 53142 PG 03579 36,500 TXBBS BLIND BROOK SEW 36,500 TO C
# RYE NY 10580 BANK COR TXCWD CO WATER DIST 36,500 TO M
# FULL MKT VAL 2,896,825 TXREF REFUSE DISPOSAL 36,500 TO M
# ----------------------------------------
# Processing Record in Section 30:
# 139-15-1-11
# ----------------------------------------
# Processing Record in Section 31:
# 162 JULIAN ST HOMESTEAD
# 139-15-1-11 210 1 FAMILY RES COUNTY TAXABLE 19,850
# SANTUCCI JUAN F & RYE CITY SCHOOLS 850 CITY TAXABLE 19,850
# AUGUSTINA M RUEDA ACREAGE 0.09 SCHOOL TAXABLE 19,850
# 162 JULIAN ST BANK COR 19,850 TXBBS BLIND BROOK SEW 19,850 TO C
# RYE NY 10580 FULL MKT VAL 1,575,396 TXCWD CO WATER DIST 19,850 TO M
# TXREF REFUSE DISPOSAL 19,850 TO M
# ----------------------------------------
# Processing Record in Section 32:
# 139-15-1-12-1
# ----------------------------------------
# Processing Record in Section 33:
# 114 GRANDVIEW AVE HOMESTEAD
# 139-15-1-12-1 210 1 FAMILY RES COUNTY TAXABLE 69,000
# MEDOW ERIC & RYE CITY SCHOOLS 9,200 CITY TAXABLE 69,000
# LEA MEDOW ACREAGE 1.00 SCHOOL TAXABLE 69,000
# 114 GRANDVIEW AVE DEED BK 51042 PG 03012 69,000 TXBBS BLIND BROOK SEW 69,000 TO C
# RYE NY 10580 FULL MKT VAL 5,476,190 TXCWD CO WATER DIST 69,000 TO M
# TXREF REFUSE DISPOSAL 69,000 TO M
# ----------------------------------------
# Processing Record in Section 34:
# 139-15-1-12-2
# ----------------------------------------
# Processing Record in Section 35:
# 4 JULIAN ST HOMESTEAD
# 139-15-1-12-2 210 1 FAMILY RES COUNTY TAXABLE 26,800
# SUZUKI ELIZABETH L RYE CITY SCHOOLS 8,200 CITY TAXABLE 26,800
# SUZUKI DAN J ACREAGE 0.51 SCHOOL TAXABLE 26,800
# 4 JULIAN ST DEED BK 57114 PG 3392 26,800 TXBBS BLIND BROOK SEW 26,800 TO C
# RYE NY 10580 BANK COR TXCWD CO WATER DIST 26,800 TO M
# FULL MKT VAL 2,126,984 TXREF REFUSE DISPOSAL 26,800 TO M
# ----------------------------------------
# Processing Record in Section 36:
# STATE OF NEW YORK 2024 C I T Y F I N A L R O L L PAGE: 4
# COUNTY: WESTCHESTER T A X A B L E SECTION OF THE ROLL - 1 ROLL PRINT DATE: 9/16/2024
# CITY OF RYE PARCEL ID ORDER VALUATION DATE: 7/1/2023
# SWIS: 551400 (CITY OF RYE) UNIFORM PERCENT OF VALUE = 1.26 TAXABLE STATUS DATE: 5/1/2024
# TAX MAP PARCEL ID CD PROPERTY LOCATION & CLASS ASSESSMENT EXEMPTION CODE-----------COUNTY-----CITY-----SCHOOL
# CURRENT OWNERS NAME SCHOOL DISTRICT ---LAND--- TAX DESCRIPTION TAXABLE VALUE
# CURRENT OWNERS ADDRESS PARCEL SIZE/GRID COORD --TOTAL--- SPECIAL DISTRICTS
# ----------------------------------------
# Skipping record due to PAGE in Property Address: STATE OF NEW YORK 2024 C I T Y F I N A L R O L L PAGE: 4
# Processing Record in Section 37:
# 139-15-1-13-1
# ----------------------------------------
# Processing Record in Section 38:
# 3 COPE CIR HOMESTEAD
# 139-15-1-13-1 210 1 FAMILY RES COUNTY TAXABLE 37,475
# BURKE ALIX RYE CITY SCHOOLS 7,400 CITY TAXABLE 37,475
# BURKE KEVIN SPLIT WITH TOWN OF RYE SCHOOL TAXABLE 37,475
# 3 COPE CIR ACREAGE 0.46 37,475 TXBBS BLIND BROOK SEW 37,475 TO C
# RYE NY 10580 DEED BK 60335 PG 3919 TXCWD CO WATER DIST 37,475 TO M
# BANK COR TXREF REFUSE DISPOSAL 37,475 TO M
# FULL MKT VAL 2,974,206
# ----------------------------------------
# Processing Record in Section 39:
# 139-15-1-13-2
# ----------------------------------------
# Processing Record in Section 40:
# 5 COPE CIR HOMESTEAD
# 139-15-1-13-2 311 RES VACANT LAND COUNTY TAXABLE 1,600
# WADE CHRISTIAN P RYE CITY SCHOOLS 1,600 CITY TAXABLE 1,600
# WADE CRISTINA D ACREAGE 0.12 SCHOOL TAXABLE 1,600
# 5 COPE CIRCLE DEED BK 59119 PG 3030 1,600 TXBBS BLIND BROOK SEW 1,600 TO C
# RYE NY 10580 BANK COR TXCWD CO WATER DIST 1,600 TO M
# FULL MKT VAL 126,984 TXREF REFUSE DISPOSAL 1,600 TO M
# ----------------------------------------
# Processing Record in Section 41:
# 139-15-1-13-3
# ----------------------------------------
# Processing Record in Section 42:
# 4 COPE CIR HOMESTEAD
# 139-15-1-13-3 210 1 FAMILY RES COUNTY TAXABLE 22,750
# KEITH G ANDREW RYE CITY SCHOOLS 6,300 CITY TAXABLE 22,750
# SUZANNA S KEITH ACREAGE 0.40 SCHOOL TAXABLE 22,750
# 4 COPE CIRCLE BANK COR 22,750 TXBBS BLIND BROOK SEW 22,750 TO C
# RYE NY 10580 FULL MKT VAL 1,805,555 TXCWD CO WATER DIST 22,750 TO M
# TXREF REFUSE DISPOSAL 22,750 TO M
# ----------------------------------------
# Processing Record in Section 43:
# 139-15-1-13-4
# ----------------------------------------
# Processing Record in Section 44:
# 95 HILLSIDE RD HOMESTEAD
# 139-15-1-13-4 210 1 FAMILY RES COUNTY TAXABLE 25,750
# CONGAVAGE NICHOLAS & RYE CITY SCHOOLS 7,550 CITY TAXABLE 25,750
# JOANNE CONGAVAGE ACREAGE 0.48 SCHOOL TAXABLE 25,750
# 95 HILLSIDE RD DEED BK 48074 PG 0419 25,750 TXBBS BLIND BROOK SEW 25,750 TO C
# RYE NY 10580 BANK COR TXCWD CO WATER DIST 25,750 TO M
# FULL MKT VAL 2,043,650 TXREF REFUSE DISPOSAL 25,750 TO M
# ----------------------------------------
# Processing Record in Section 45:
# 139-15-1-13-5
# ----------------------------------------
# Processing Record in Section 46:
# 2 COPE CIR HOMESTEAD
# 139-15-1-13-5 210 1 FAMILY RES COUNTY TAXABLE 23,500
# TRAVERS, SCOTT RYE CITY SCHOOLS 7,900 CITY TAXABLE 23,500
# KATHERINE TRAVERS ACREAGE 0.52 SCHOOL TAXABLE 23,500
# 2 COPE CIR DEED BK 64175 PG 3017 23,500 TXBBS BLIND BROOK SEW 23,500 TO C
# RYE NY 10580 FULL MKT VAL 1,865,079 TXCWD CO WATER DIST 23,500 TO M
# TXREF REFUSE DISPOSAL 23,500 TO M
# ----------------------------------------
# Processing Record in Section 47:
# STATE OF NEW YORK 2024 C I T Y F I N A L R O L L PAGE: 5
# COUNTY: WESTCHESTER T A X A B L E SECTION OF THE ROLL - 1 ROLL PRINT DATE: 9/16/2024
# CITY OF RYE PARCEL ID ORDER VALUATION DATE: 7/1/2023
# SWIS: 551400 (CITY OF RYE) UNIFORM PERCENT OF VALUE = 1.26 TAXABLE STATUS DATE: 5/1/2024
# TAX MAP PARCEL ID CD PROPERTY LOCATION & CLASS ASSESSMENT EXEMPTION CODE-----------COUNTY-----CITY-----SCHOOL
# CURRENT OWNERS NAME SCHOOL DISTRICT ---LAND--- TAX DESCRIPTION TAXABLE VALUE
# CURRENT OWNERS ADDRESS PARCEL SIZE/GRID COORD --TOTAL--- SPECIAL DISTRICTS
# ----------------------------------------
# Skipping record due to PAGE in Property Address: STATE OF NEW YORK 2024 C I T Y F I N A L R O L L PAGE: 5
# Processing Record in Section 48:
# 139-15-1-14
# ----------------------------------------
# Processing Record in Section 49:
# 91 HILLSIDE RD HOMESTEAD
# 139-15-1-14 210 1 FAMILY RES COUNTY TAXABLE 35,700
# EHRLICH BRETT S RYE CITY SCHOOLS 10,700 CITY TAXABLE 35,700
# EHRLICH WHITNEY W ACREAGE 0.68 SCHOOL TAXABLE 35,700
# 91 HILLSIDE RD DEED BK 53120 PG 03530 35,700 TXBBS BLIND BROOK SEW 35,700 TO C
# RYE NY 10580 FULL MKT VAL 2,833,333 TXCWD CO WATER DIST 35,700 TO M
# TXREF REFUSE DISPOSAL 35,700 TO M
# ----------------------------------------
# Processing Record in Section 50:
# 139-15-1-15
# ----------------------------------------
# Processing Record in Section 51:
# 89 HILLSIDE RD HOMESTEAD
# 139-15-1-15 210 1 FAMILY RES COUNTY TAXABLE 37,000
# TALT ROBERT RYE CITY SCHOOLS 6,900 CITY TAXABLE 37,000
# LINDA TALT ACREAGE 0.48 SCHOOL TAXABLE 37,000
# 89 HILLSIDE RD DEED BK 41178 PG 111 37,000 TXBBS BLIND BROOK SEW 37,000 TO C
# RYE NY 10580 FULL MKT VAL 2,936,507 TXCWD CO WATER DIST 37,000 TO M
# TXREF REFUSE DISPOSAL 37,000 TO M
# ----------------------------------------
# Processing Record in Section 52:
# 139-15-1-16
# ----------------------------------------
# Processing Record in Section 53:
# 81 HILLSIDE RD HOMESTEAD
# 139-15-1-16 210 1 FAMILY RES COUNTY TAXABLE 60,840
# MITCHELL BARRY P JR RYE CITY SCHOOLS 8,300 CITY TAXABLE 60,840
# MITCHELL ELISABETH M ACREAGE 0.80 SCHOOL TAXABLE 60,840
# 81 HILLSIDE ROAD DEED BK 52339 PG 03572 60,840 TXBBS BLIND BROOK SEW 60,840 TO C
# RYE NY 10580 FULL MKT VAL 4,828,571 TXCWD CO WATER DIST 60,840 TO M
# TXREF REFUSE DISPOSAL 60,840 TO M
# ----------------------------------------
# Processing Record in Section 54:
# 139-15-1-17
# ----------------------------------------
# Processing Record in Section 55:
# 77 HILLSIDE RD HOMESTEAD
# 139-15-1-17 210 1 FAMILY RES COUNTY TAXABLE 51,000
# KING MICHAEL T RYE CITY SCHOOLS 8,800 CITY TAXABLE 51,000
# KING LISA ACREAGE 0.90 SCHOOL TAXABLE 51,000
# 77 HILLSIDE RD DEED BK 60226 PG 3838 51,000 TXBBS BLIND BROOK SEW 51,000 TO C
# RYE NY 10580 FULL MKT VAL 4,047,619 TXCWD CO WATER DIST 51,000 TO M
# TXREF REFUSE DISPOSAL 51,000 TO M
# ----------------------------------------
# Processing Record in Section 56:
# 139-15-1-18
# ----------------------------------------
# Processing Record in Section 57:
# 105 GRANDVIEW AVE HOMESTEAD
# 139-15-1-18 210 1 FAMILY RES COUNTY TAXABLE 40,475
# MONGILLO STEPHEN A RYE CITY SCHOOLS 7,500 CITY TAXABLE 40,475
# ELISABETH G THORINGTON ACREAGE 0.60 SCHOOL TAXABLE 40,475
# 105 GRANDVIEW AVE DEED BK 43136 PG 0504 40,475 TXBBS BLIND BROOK SEW 40,475 TO C
# RYE NY 10580 FULL MKT VAL 3,212,301 TXCWD CO WATER DIST 40,475 TO M
# TXREF REFUSE DISPOSAL 40,475 TO M
# ----------------------------------------
# Processing Record in Section 58:
# 139-15-1-19
# ----------------------------------------
# Processing Record in Section 59:
# 119 GRANDVIEW AVE HOMESTEAD
# 139-15-1-19 210 1 FAMILY RES COUNTY TAXABLE 19,850
# JENKINS NICOLE T RYE CITY SCHOOLS 7,600 CITY TAXABLE 19,850
# 119 GRANDVIEW AVE ACREAGE 0.62 SCHOOL TAXABLE 19,850
# RYE NY 10580 DEED BK 48197 PG 0390 19,850 TXBBS BLIND BROOK SEW 19,850 TO C
# BANK COR TXCWD CO WATER DIST 19,850 TO M
# FULL MKT VAL 1,575,396 TXREF REFUSE DISPOSAL 19,850 TO M
# ----------------------------------------
# Processing Record in Section 60:
# STATE OF NEW YORK 2024 C I T Y F I N A L R O L L PAGE: 6
# COUNTY: WESTCHESTER T A X A B L E SECTION OF THE ROLL - 1 ROLL PRINT DATE: 9/16/2024
# CITY OF RYE PARCEL ID ORDER VALUATION DATE: 7/1/2023
# SWIS: 551400 (CITY OF RYE) UNIFORM PERCENT OF VALUE = 1.26 TAXABLE STATUS DATE: 5/1/2024
# TAX MAP PARCEL ID CD PROPERTY LOCATION & CLASS ASSESSMENT EXEMPTION CODE-----------COUNTY-----CITY-----SCHOOL
# CURRENT OWNERS NAME SCHOOL DISTRICT ---LAND--- TAX DESCRIPTION TAXABLE VALUE
# CURRENT OWNERS ADDRESS PARCEL SIZE/GRID COORD --TOTAL--- SPECIAL DISTRICTS
# ----------------------------------------
# Skipping record due to PAGE in Property Address: STATE OF NEW YORK 2024 C I T Y F I N A L R O L L PAGE: 6
# Processing Record in Section 61:
# 139-15-1-20
# ----------------------------------------
# Processing Record in Section 62:
# 129 GRANDVIEW AVE HOMESTEAD
# 139-15-1-20 210 1 FAMILY RES COUNTY TAXABLE 38,750
# BROWNE DAIRE C RYE CITY SCHOOLS 7,400 CITY TAXABLE 38,750
# MORGAN MARINA ACREAGE 0.58 SCHOOL TAXABLE 38,750
# 129 GRANDVIEW AVE DEED BK 56095 PG 03630 38,750 TXBBS BLIND BROOK SEW 38,750 TO C
# RYE NY 10580 BANK COR TXCWD CO WATER DIST 38,750 TO M
# FULL MKT VAL 3,075,396 TXREF REFUSE DISPOSAL 38,750 TO M
# ----------------------------------------
# Processing Record in Section 63:
# 139-15-1-21-1
# ----------------------------------------
# Processing Record in Section 64:
# 139 GRANDVIEW AVE HOMESTEAD
# 139-15-1-21-1 210 1 FAMILY RES COUNTY TAXABLE 61,150
# FURBER WILLIAM RYE CITY SCHOOLS 11,600 CITY TAXABLE 61,150
# FURBER SARA ACREAGE 1.35 SCHOOL TAXABLE 61,150
# 139 GRANDVIEW AVE DEED BK 53263 PG 03115 61,150 TXBBS BLIND BROOK SEW 61,150 TO C
# RYE NY 10580 FULL MKT VAL 4,853,174 TXCWD CO WATER DIST 61,150 TO M
# TXREF REFUSE DISPOSAL 61,150 TO M
# ----------------------------------------
# Processing Record in Section 65:
# 139-15-1-21-2
# ----------------------------------------
# Processing Record in Section 66:
# 133 GRANDVIEW AVE HOMESTEAD
# 139-15-1-21-2 210 1 FAMILY RES COUNTY TAXABLE 44,800
# ZINGG MARTIN RYE CITY SCHOOLS 7,800 CITY TAXABLE 44,800
# ZINGG DEBORAH ACREAGE 0.67 SCHOOL TAXABLE 44,800
# 133 GRANDVIEW AVE DEED BK 60064 PG 3115 44,800 TXBBS BLIND BROOK SEW 44,800 TO C
# RYE NY 10580 FULL MKT VAL 3,555,555 TXCWD CO WATER DIST 44,800 TO M
# TXREF REFUSE DISPOSAL 44,800 TO M
# ----------------------------------------
# Processing Record in Section 67:
# 139-15-1-22
# ----------------------------------------
# Processing Record in Section 68:
# 106 EVERGREEN AVE HOMESTEAD
# 139-15-1-22 210 1 FAMILY RES COUNTY TAXABLE 43,200
# PASTOR JENNIE TRUST RYE CITY SCHOOLS 9,600 CITY TAXABLE 43,200
# 106 EVERGREEN AVE ACREAGE 1.05 SCHOOL TAXABLE 43,200
# RYE NY 10580 DEED BK 63230 PG 3039 43,200 TXBBS BLIND BROOK SEW 43,200 TO C
# BANK COR TXCWD CO WATER DIST 43,200 TO M
# FULL MKT VAL 3,428,571 TXREF REFUSE DISPOSAL 43,200 TO M
# ----------------------------------------
# Processing Record in Section 69:
# 139-15-1-23
# ----------------------------------------
# Processing Record in Section 70:
# 100 EVERGREEN AVE HOMESTEAD
# 139-15-1-23 210 1 FAMILY RES COUNTY TAXABLE 54,100
# BARTROP ANDREW RYE CITY SCHOOLS 10,000 CITY TAXABLE 54,100
# BARTROP MARLIESHA ACREAGE 1.21 SCHOOL TAXABLE 54,100
# 100 EVERGREEN AVE DEED BK 64015 PG 3060 54,100 TXBBS BLIND BROOK SEW 54,100 TO C
# RYE NY 10580 FULL MKT VAL 4,293,650 TXCWD CO WATER DIST 54,100 TO M
# TXREF REFUSE DISPOSAL 54,100 TO M
# ----------------------------------------
# Processing Record in Section 71:
# 139-15-1-24
# ----------------------------------------
# Processing Record in Section 72:
# 96 EVERGREEN AVE HOMESTEAD
# 139-15-1-24 210 1 FAMILY RES COUNTY TAXABLE 48,975
# BRISTOW COLIN RYE CITY SCHOOLS 8,400 CITY TAXABLE 48,975
# BRISTOW DIANA ACREAGE 0.78 SCHOOL TAXABLE 48,975
# 96 EVERGREEN AVE DEED BK 60227 PG 3249 48,975 TXBBS BLIND BROOK SEW 48,975 TO C
# RYE NY 10580 FULL MKT VAL 3,886,904 TXCWD CO WATER DIST 48,975 TO M
# TXREF REFUSE DISPOSAL 48,975 TO M
# ----------------------------------------
# Processing Record in Section 73:
# STATE OF NEW YORK 2024 C I T Y F I N A L R O L L PAGE: 7
# COUNTY: WESTCHESTER T A X A B L E SECTION OF THE ROLL - 1 ROLL PRINT DATE: 9/16/2024
# CITY OF RYE PARCEL ID ORDER VALUATION DATE: 7/1/2023
# SWIS: 551400 (CITY OF RYE) UNIFORM PERCENT OF VALUE = 1.26 TAXABLE STATUS DATE: 5/1/2024
# TAX MAP PARCEL ID CD PROPERTY LOCATION & CLASS ASSESSMENT EXEMPTION CODE-----------COUNTY-----CITY-----SCHOOL
# CURRENT OWNERS NAME SCHOOL DISTRICT ---LAND--- TAX DESCRIPTION TAXABLE VALUE
# CURRENT OWNERS ADDRESS PARCEL SIZE/GRID COORD --TOTAL--- SPECIAL DISTRICTS
# ----------------------------------------
# Skipping record due to PAGE in Property Address: STATE OF NEW YORK 2024 C I T Y F I N A L R O L L PAGE: 7
# Processing Record in Section 74:
# 139-15-1-25
# ----------------------------------------
# Processing Record in Section 75:
# 55 HILLSIDE RD HOMESTEAD
# 139-15-1-25 210 1 FAMILY RES COUNTY TAXABLE 67,200
# EDELMAN MARTIN L & RYE CITY SCHOOLS 12,100 CITY TAXABLE 67,200
# NANCY H EDELMAN ACREAGE 1.50 SCHOOL TAXABLE 67,200
# 55 HILLSIDE RD FULL MKT VAL 5,333,333 67,200 TXBBS BLIND BROOK SEW 67,200 TO C
# RYE NY 10580 TXCWD CO WATER DIST 67,200 TO M
# TXREF REFUSE DISPOSAL 67,200 TO M
# ----------------------------------------
# Processing Record in Section 76:
# 139-15-1-26
# ----------------------------------------
# Processing Record in Section 77:
# 93 EVERGREEN AVE HOMESTEAD
# 139-15-1-26 210 1 FAMILY RES COUNTY TAXABLE 41,000
# CAPONITI MEGHAN LAURIE RYE CITY SCHOOLS 7,000 CITY TAXABLE 41,000
# 93 EVERGREEN AVE ACREAGE 0.64 SCHOOL TAXABLE 41,000
# RYE NY 10580 DEED BK 46320 PG 0151 41,000 TXBBS BLIND BROOK SEW 41,000 TO C
# FULL MKT VAL 3,253,968 TXCWD CO WATER DIST 41,000 TO M
# TXREF REFUSE DISPOSAL 41,000 TO M
# ----------------------------------------
# Processing Record in Section 78:
# 139-15-1-27
# ----------------------------------------
# Processing Record in Section 79:
# 17 HILLSIDE RD HOMESTEAD
# 139-15-1-27 210 1 FAMILY RES COUNTY TAXABLE 44,675
# VYAS VIVEK & PRIYA RYE CITY SCHOOLS 6,600 CITY TAXABLE 44,675
# 17 HILLSIDE RD ACREAGE 0.38 SCHOOL TAXABLE 44,675
# RYE NY 10580 DEED BK 63218 PG 3008 44,675 TXBBS BLIND BROOK SEW 44,675 TO C
# FULL MKT VAL 3,545,634 TXCWD CO WATER DIST 44,675 TO M
# TXREF REFUSE DISPOSAL 44,675 TO M
# ----------------------------------------
# Processing Record in Section 80:
# 139-15-1-28
# ----------------------------------------
# Processing Record in Section 81:
# 95 EVERGREEN AVE HOMESTEAD
# 139-15-1-28 210 1 FAMILY RES COUNTY TAXABLE 25,900
# ROONEY JOSEPH T RYE CITY SCHOOLS 9,000 CITY TAXABLE 25,900
# ROONEY EVAS H ACREAGE 0.90 SCHOOL TAXABLE 25,900
# 95 EVERGREEN AVE DEED BK 59134 PG 3523 25,900 TXBBS BLIND BROOK SEW 25,900 TO C
# RYE NY 10580 BANK COR TXCWD CO WATER DIST 25,900 TO M
# FULL MKT VAL 2,055,555 TXREF REFUSE DISPOSAL 25,900 TO M
# ----------------------------------------
# Processing Record in Section 82:
# 139-15-1-29
# ----------------------------------------
# Processing Record in Section 83:
# 105 EVERGREEN AVE HOMESTEAD
# 139-15-1-29 210 1 FAMILY RES COUNTY TAXABLE 100,200
# NIEHAUS ROBERT H & RYE CITY SCHOOLS 13,250 CITY TAXABLE 100,200
# KATE S NIEHAUS ACREAGE 1.40 SCHOOL TAXABLE 100,200
# 770 PARK AVE #16D FULL MKT VAL 7,952,380 100,200 TXBBS BLIND BROOK SEW 100,200 TO C
# NY NY 10021 TXCWD CO WATER DIST 100,200 TO M
# TXREF REFUSE DISPOSAL 100,200 TO M
# ----------------------------------------
# Processing Record in Section 84:
# 139-15-1-30
# ----------------------------------------
# Processing Record in Section 85:
# 115 EVERGREEN AVE HOMESTEAD
# 139-15-1-30 210 1 FAMILY RES COUNTY TAXABLE 56,100
# HEFFERNAN JOHN & RYE CITY SCHOOLS 11,600 CITY TAXABLE 56,100
# JUNE HEFFERNAN ACREAGE 1.35 SCHOOL TAXABLE 56,100
# 115 EVERGREEN AVE FULL MKT VAL 4,452,380 56,100 TXBBS BLIND BROOK SEW 56,100 TO C
# RYE NY 10580 TXCWD CO WATER DIST 56,100 TO M
# TXREF REFUSE DISPOSAL 56,100 TO M
# ----------------------------------------
# Processing Record in Section 86:
# STATE OF NEW YORK 2024 C I T Y F I N A L R O L L PAGE: 8
# COUNTY: WESTCHESTER T A X A B L E SECTION OF THE ROLL - 1 ROLL PRINT DATE: 9/16/2024
# CITY OF RYE PARCEL ID ORDER VALUATION DATE: 7/1/2023
# SWIS: 551400 (CITY OF RYE) UNIFORM PERCENT OF VALUE = 1.26 TAXABLE STATUS DATE: 5/1/2024
# TAX MAP PARCEL ID CD PROPERTY LOCATION & CLASS ASSESSMENT EXEMPTION CODE-----------COUNTY-----CITY-----SCHOOL
# CURRENT OWNERS NAME SCHOOL DISTRICT ---LAND--- TAX DESCRIPTION TAXABLE VALUE
# CURRENT OWNERS ADDRESS PARCEL SIZE/GRID COORD --TOTAL--- SPECIAL DISTRICTS
# ----------------------------------------
# Skipping record due to PAGE in Property Address: STATE OF NEW YORK 2024 C I T Y F I N A L R O L L PAGE: 8
# Processing Record in Section 87:
# 139-15-1-31
# ----------------------------------------
# Processing Record in Section 88:
# 60 RIDGE ST HOMESTEAD
# 139-15-1-31 210 1 FAMILY RES 41854 RES STAR 1,180
# MALIK SHAHID & SILVAT RYE CITY SCHOOLS 8,000 COUNTY TAXABLE 27,700
# 60 RIDGE ST ACREAGE 1.06 CITY TAXABLE 27,700
# RYE NY 10580 FULL MKT VAL 2,198,412 27,700 SCHOOL TAXABLE 26,520
# TXBBS BLIND BROOK SEW 27,700 TO C
# TXCWD CO WATER DIST 27,700 TO M
# TXREF REFUSE DISPOSAL 27,700 TO M
# ----------------------------------------
# Processing Record in Section 89:
# 139-15-1-32
# ----------------------------------------
# Processing Record in Section 90:
# 50 RIDGE ST HOMESTEAD
# 139-15-1-32 210 1 FAMILY RES COUNTY TAXABLE 22,975
# 50 RIDGE LLC RYE CITY SCHOOLS 8,000 CITY TAXABLE 22,975
# 50 RIDGE ST ACREAGE 1.04 SCHOOL TAXABLE 22,975
# RYE NY 10580 DEED BK 64023 PG 3181 22,975 TXBBS BLIND BROOK SEW 22,975 TO C
# FULL MKT VAL 1,823,412 TXCWD CO WATER DIST 22,975 TO M
# TXREF REFUSE DISPOSAL 22,975 TO M
# ----------------------------------------
# Processing Record in Section 91:
# 139-15-1-33
# ----------------------------------------
# Processing Record in Section 92:
# 30 RIDGE ST HOMESTEAD
# 139-15-1-33 210 1 FAMILY RES COUNTY TAXABLE 36,900
# O CONNOR WILLIAM & RYE CITY SCHOOLS 8,600 CITY TAXABLE 36,900
# ANDREA O CONNOR ACREAGE 1.29 SCHOOL TAXABLE 36,900
# 30 RIDGE ST FULL MKT VAL 2,928,571 36,900 TXBBS BLIND BROOK SEW 36,900 TO C
# RYE NY 10580 TXCWD CO WATER DIST 36,900 TO M
# TXREF REFUSE DISPOSAL 36,900 TO M
# ----------------------------------------
# Processing Record in Section 93:
# 139-15-1-34
# ----------------------------------------
# Processing Record in Section 94:
# 15 HILLSIDE RD HOMESTEAD
# 139-15-1-34 210 1 FAMILY RES COUNTY TAXABLE 42,000
# KAVANAGH MORGAN P RYE CITY SCHOOLS 9,400 CITY TAXABLE 42,000
# KAVANAGH CHARLOTTE E ACREAGE 1.00 SCHOOL TAXABLE 42,000
# 15 HILLSIDE RD DEED BK 59176 PG 3673 42,000 TXBBS BLIND BROOK SEW 42,000 TO C
# RYE NY 10580 FULL MKT VAL 3,333,333 TXCWD CO WATER DIST 42,000 TO M
# TXREF REFUSE DISPOSAL 42,000 TO M
# ----------------------------------------
# Processing Record in Section 95:
# 139-15-1-35
# ----------------------------------------
# Processing Record in Section 96:
# 1 HILLSIDE RD HOMESTEAD
# 139-15-1-35 210 1 FAMILY RES COUNTY TAXABLE 32,900
# GRAHAM VICTORIA RYE CITY SCHOOLS 7,500 CITY TAXABLE 32,900
# MCMAHON PAUL R ACREAGE 0.93 SCHOOL TAXABLE 32,900
# 1 HILLSIDE RD DEED BK 62277 PG 3059 32,900 TXBBS BLIND BROOK SEW 32,900 TO C
# RYE NY 10580 FULL MKT VAL 2,611,111 TXCWD CO WATER DIST 32,900 TO M
# TXREF REFUSE DISPOSAL 32,900 TO M
# ----------------------------------------
# Processing Record in Section 97:
# STATE OF NEW YORK 2024 C I T Y F I N A L R O L L PAGE: 9
# COUNTY: WESTCHESTER T A X A B L E SECTION OF THE ROLL - 1 ROLL PRINT DATE: 9/16/2024
# CITY OF RYE PARCEL ID ORDER VALUATION DATE: 7/1/2023
# SWIS: 551400 (CITY OF RYE) UNIFORM PERCENT OF VALUE = 1.26 TAXABLE STATUS DATE: 5/1/2024
# TAX MAP PARCEL ID CD PROPERTY LOCATION & CLASS ASSESSMENT EXEMPTION CODE-----------COUNTY-----CITY-----SCHOOL
# CURRENT OWNERS NAME SCHOOL DISTRICT ---LAND--- TAX DESCRIPTION TAXABLE VALUE
# CURRENT OWNERS ADDRESS PARCEL SIZE/GRID COORD --TOTAL--- SPECIAL DISTRICTS
# ----------------------------------------
# Skipping record due to PAGE in Property Address: STATE OF NEW YORK 2024 C I T Y F I N A L R O L L PAGE: 9
# Processing Record in Section 98:
# 139-15-1-36
# ----------------------------------------
# Processing Record in Section 99:
# 335 PURCHASE ST HOMESTEAD
# 139-15-1-36 210 1 FAMILY RES COUNTY TAXABLE 37,000
# BIANCHI MARC & MARY RYE CITY SCHOOLS 7,100 CITY TAXABLE 37,000
# 335 PURCHASE ST ACREAGE 0.80 SCHOOL TAXABLE 37,000
# RYE NY 10580 DEED BK 64162 PG 3230 37,000 TXBBS BLIND BROOK SEW 37,000 TO C
# BANK COR TXCWD CO WATER DIST 37,000 TO M
# FULL MKT VAL 2,936,507 TXREF REFUSE DISPOSAL 37,000 TO M
# ----------------------------------------
# Processing Record in Section 100:
# 139-15-1-37
# ----------------------------------------
# Processing Record in Section 101:
# 343 PURCHASE ST HOMESTEAD
# 139-15-1-37 210 1 FAMILY RES COUNTY TAXABLE 32,250
# 343 PURCHASE ST LLC RYE CITY SCHOOLS 8,100 CITY TAXABLE 32,250
# 111 MILL ST ACREAGE 1.10 SCHOOL TAXABLE 32,250
# GREENWICH CT 08630 DEED BK 62200 PG 3325 32,250 TXBBS BLIND BROOK SEW 32,250 TO C
# BANK COR TXCWD CO WATER DIST 32,250 TO M
# FULL MKT VAL 2,559,523 TXREF REFUSE DISPOSAL 32,250 TO M
# ----------------------------------------
# Processing Record in Section 102:
# 139-18-1-1-1
# ----------------------------------------
# Processing Record in Section 103:
# 8 UPPER DOGWOOD LN HOMESTEAD
# 139-18-1-1-1 210 1 FAMILY RES COUNTY TAXABLE 75,400
# SOBOL EDWARD P RYE CITY SCHOOLS 37,400 CITY TAXABLE 75,400
# SOBOL BINH-MINH H ACREAGE 1.98 SCHOOL TAXABLE 75,400
# 6-8 UPPER DOGWOOD LN DEED BK 62262 PG 3309 75,400 TXBBS BLIND BROOK SEW 75,400 TO C
# RYE NY 10580 FULL MKT VAL 5,984,126 TXCWD CO WATER DIST 75,400 TO M
# TXREF REFUSE DISPOSAL 75,400 TO M
# ----------------------------------------
# Processing Record in Section 104:
# 139-18-1-1-2
# ----------------------------------------
# Processing Record in Section 105:
# 6 UPPER DOGWOOD LN HOMESTEAD
# 139-18-1-1-2 210 1 FAMILY RES COUNTY TAXABLE 20,950
# EOLIA TRUST RYE CITY SCHOOLS 20,850 CITY TAXABLE 20,950
# 6-8 UPPER DOGWOOD LN ACREAGE 1.07 SCHOOL TAXABLE 20,950
# RYE NY 10580 DEED BK 62262 PG 3347 20,950 TXBBS BLIND BROOK SEW 20,950 TO C
# FULL MKT VAL 1,662,698 TXCWD CO WATER DIST 20,950 TO M
# TXREF REFUSE DISPOSAL 20,950 TO M
# ----------------------------------------
# Processing Record in Section 106:
# 139-18-1-2
# ----------------------------------------
# Processing Record in Section 107:
# 183 HIGHLAND RD HOMESTEAD
# 139-18-1-2 311 RES VACANT LAND COUNTY TAXABLE 1,750
# COTTET MICHAEL K RYE CITY SCHOOLS 1,750 CITY TAXABLE 1,750
# BURTON ELIZABETH ACREAGE 0.16 SCHOOL TAXABLE 1,750
# 183 HIGHLAND RD DEED BK 62221 PG 3534 1,750 TXBBS BLIND BROOK SEW 1,750 TO C
# RYE NY 10580 BANK COR TXCWD CO WATER DIST 1,750 TO M
# FULL MKT VAL 138,888 TXREF REFUSE DISPOSAL 1,750 TO M
# ----------------------------------------
# Processing Record in Section 108:
# 139-18-1-3
# ----------------------------------------
# Processing Record in Section 109:
# 181 HIGHLAND RD HOMESTEAD
# 139-18-1-3 311 RES VACANT LAND COUNTY TAXABLE 1,050
# WEISS GREGORY RYE CITY SCHOOLS 1,050 CITY TAXABLE 1,050
# WEISS RACHEL ACREAGE 0.09 SCHOOL TAXABLE 1,050
# 181 HIGHLAND RD DEED BK 51354 PG 03560 1,050 TXBBS BLIND BROOK SEW 1,050 TO C
# RYE NY 10580 FULL MKT VAL 83,333 TXCWD CO WATER DIST 1,050 TO M
# TXREF REFUSE DISPOSAL 1,050 TO M
# ----------------------------------------
# Processing Record in Section 110:
# STATE OF NEW YORK 2024 C I T Y F I N A L R O L L PAGE: 10
# COUNTY: WESTCHESTER T A X A B L E SECTION OF THE ROLL - 1 ROLL PRINT DATE: 9/16/2024
# CITY OF RYE PARCEL ID ORDER VALUATION DATE: 7/1/2023
# SWIS: 551400 (CITY OF RYE) UNIFORM PERCENT OF VALUE = 1.26 TAXABLE STATUS DATE: 5/1/2024
# TAX MAP PARCEL ID CD PROPERTY LOCATION & CLASS ASSESSMENT EXEMPTION CODE-----------COUNTY-----CITY-----SCHOOL
# CURRENT OWNERS NAME SCHOOL DISTRICT ---LAND--- TAX DESCRIPTION TAXABLE VALUE
# CURRENT OWNERS ADDRESS PARCEL SIZE/GRID COORD --TOTAL--- SPECIAL DISTRICTS
# ----------------------------------------
# Skipping record due to PAGE in Property Address: STATE OF NEW YORK 2024 C I T Y F I N A L R O L L PAGE: 10
# Processing Record in Section 111:
# 139-18-1-4
# ----------------------------------------
# Processing Record in Section 112:
# 4 UPPER DOGWOOD LN HOMESTEAD
# 139-18-1-4 210 1 FAMILY RES COUNTY TAXABLE 67,100
# KEOUGH PATRICK J RYE CITY SCHOOLS 12,450 CITY TAXABLE 67,100
# KEOUGH MEGAN ACREAGE 0.97 SCHOOL TAXABLE 67,100
# 4 UPPER DOGWOOD LN DEED BK 61019 PG 3792 67,100 TXBBS BLIND BROOK SEW 67,100 TO C
# RYE NY 10580 FULL MKT VAL 5,325,396 TXCWD CO WATER DIST 67,100 TO M
# TXREF REFUSE DISPOSAL 67,100 TO M
# ----------------------------------------
# Processing Record in Section 113:
# 139-18-1-5
# ----------------------------------------
# Processing Record in Section 114:
# 2 UPPER DOGWOOD LN HOMESTEAD
# 139-18-1-5 210 1 FAMILY RES COUNTY TAXABLE 64,400
# SMITH H OLIVER RYE CITY SCHOOLS 33,900 CITY TAXABLE 64,400
# SMITH SARAH ACREAGE 1.70 SCHOOL TAXABLE 64,400
# 2 UPPER DOGWOOD LN DEED BK 57339 PG 3318 64,400 TXBBS BLIND BROOK SEW 64,400 TO C
# RYE NY 10580 FULL MKT VAL 5,111,111 TXCWD CO WATER DIST 64,400 TO M
# TXREF REFUSE DISPOSAL 64,400 TO M
# ----------------------------------------
# Processing Record in Section 115:
# 139-18-1-6
# ----------------------------------------
# Processing Record in Section 116:
# 105 DOGWOOD LN HOMESTEAD
# 139-18-1-6 210 1 FAMILY RES COUNTY TAXABLE 55,000
# TISDALE EMILY K RYE CITY SCHOOLS 9,200 CITY TAXABLE 55,000
# 105 DOGWOOD LN ACREAGE 0.85 SCHOOL TAXABLE 55,000
# RYE NY 10580 DEED BK 60160 PG 3689 55,000 TXBBS BLIND BROOK SEW 55,000 TO C
# FULL MKT VAL 4,365,079 TXCWD CO WATER DIST 55,000 TO M
# TXREF REFUSE DISPOSAL 55,000 TO M
# ----------------------------------------
# Processing Record in Section 117:
# 139-18-1-7
# ----------------------------------------
# Processing Record in Section 118:
# 95 DOGWOOD LN HOMESTEAD
# 139-18-1-7 210 1 FAMILY RES COUNTY TAXABLE 22,300
# MATSUO MEREDITH RYE CITY SCHOOLS 8,550 CITY TAXABLE 22,300
# CHINO-SHI, TOYOHIRA ACREAGE 0.55 SCHOOL TAXABLE 22,300
# 4734-4798 DEED BK 57136 PG 3553 22,300 TXBBS BLIND BROOK SEW 22,300 TO C
# SHIRAKABA-DAIRA 1-6-5 FULL MKT VAL 1,769,841 TXCWD CO WATER DIST 22,300 TO M
# 391-0213 JAPAN TXREF REFUSE DISPOSAL 22,300 TO M
# ----------------------------------------
# Processing Record in Section 119:
# 139-18-1-8-1
# ----------------------------------------
# Processing Record in Section 120:
# 91 DOGWOOD LN HOMESTEAD
# 139-18-1-8-1 GD 210 1 FAMILY RES COUNTY TAXABLE 73,900
# BOILLOT DAVID & RYE CITY SCHOOLS 15,700 CITY TAXABLE 73,900
# DEBORAH BOILLOT ACREAGE 2.05 SCHOOL TAXABLE 73,900
# 91 DOGWOOD LN FULL MKT VAL 5,865,079 73,900 TXBBS BLIND BROOK SEW 73,900 TO C
# RYE NY 10580 TXCWD CO WATER DIST 73,900 TO M
# TXREF REFUSE DISPOSAL 73,900 TO M
# ----------------------------------------
# Processing Record in Section 121:
# 139-18-1-10-1
# ----------------------------------------
# Processing Record in Section 122:
# 12 DOGWOOD LN HOMESTEAD
# 139-18-1-10-1 GD 210 1 FAMILY RES COUNTY TAXABLE 88,000
# GILROY REV TRUST RYE CITY SCHOOLS 14,600 CITY TAXABLE 88,000
# 12 DOGWOOD LN ACREAGE 1.72 SCHOOL TAXABLE 88,000
# RYE NY 10580 DEED BK 60149 PG 7594 88,000 TXBBS BLIND BROOK SEW 88,000 TO C
# FULL MKT VAL 6,984,126 TXCWD CO WATER DIST 88,000 TO M
# TXREF REFUSE DISPOSAL 88,000 TO M
# ----------------------------------------
# Total number of records extracted: 56
# Data has been extracted and saved to 'extracted_property_data_final_v4.xlsx'
